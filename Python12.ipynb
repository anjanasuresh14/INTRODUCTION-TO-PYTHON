# %% [markdown]
# <a href="https://colab.research.google.com/github/anjanasuresh14/INTRODUCTION-TO-PYTHON/blob/main/Python12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-893223b5-628e-4a95-bbfa-cf8b444a8e1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-893223b5-628e-4a95-bbfa-cf8b444a8e1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams=files.upload()
# Out:
#      <input type="file" id="files-567d7c2b-4577-497a-8bc6-27a9d2dbd935" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-567d7c2b-4577-497a-8bc6-27a9d2dbd935">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
teamgoals={'teams':['Spain','England'],'goals':[2,4]}
tg_df=pd.DataFrame(teamgoals)
print(tg_df)
# Out:
#      teams  goals
# 0    Spain      2
# 1  England      4

# %%
import pandas as pd
team={'Players':['Messi','Ronaldo','Neymar'],'Country':['Argentina','Portugal','Brazil']}
df=pd.DataFrame(team)
print(df)
# Out:
#    Players    Country
# 0    Messi  Argentina
# 1  Ronaldo   Portugal
# 2   Neymar     Brazil

# %%
import pandas as pd
marks=[40,80,60,50]
print(pd.DataFrame(marks))
# Out:
#     0
# 0  40
# 1  80
# 2  60
# 3  50

# %%
import pandas as pd
df=pd.read_csv('Supermarket_sales.csv')
#print(df.head())
#print(df.tail())
print(df['City'],df['Branch'])
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
import pandas as pd
df=pd.read_csv('Supermarket_sales.csv')
for i in df.index:
  print(df.City[i],df.Branch[i])
# Out:
# Yangon A
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Yangon A
# Naypyitaw C
# Mandalay B
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Mandalay B
# Mandalay B
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Naypyitaw C
# Mandalay B
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Naypyitaw C
# ...

# %%
from google.colab import files
player=files.upload()
# Out:
#      <input type="file" id="files-ab0d332e-8160-40e5-a9dd-29e1ecc75d33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab0d332e-8160-40e5-a9dd-29e1ecc75d33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('players_20.csv')
max_overall=df.overall.max()
max_overall_loc=df.overall.idxmax()
person=df.loc[max_overall_loc]
print(person.long_name,'has the highest overall of',max_overall)
# Out:
# Lionel Andrés Messi Cuccittini has the highest overall of 94

# %%
import pandas as pd
df=pd.read_csv('players_20.csv')
min_age=df.age.min()
min_age_loc=df.age.idxmin()
person=df.loc[min_age_loc]
print(person.long_name,'has the minimum age of',min_age)
# Out:
# Adam Hložek has the minimum age of 16

# %%
import pandas as pd
df=pd.read_csv('players_20.csv')
max_age=df.age.max()
max_age_loc=df.age.idxmax()
person=df.loc[max_age_loc]
print(person.long_name,'has the maximum age of',max_age)
# Out:
# Cristian Fernando Muñoz Hoffman has the maximum age of 42

# %%
import pandas as pd 
fifadf=pd.read_csv("players_20.csv")
max_overall=fifadf.overall.max()
print(max_overall)
# Out:
# 94

# %%
import pandas as pd 
fifadf=pd.read_csv("players_20.csv")
min_age=fifadf.age.min()

print(min_age)
# Out:
# 16

# %%
import pandas as pd 
fifadf=pd.read_csv("players_20.csv")
min_age=fifadf.age.idxmin()
print(min_age)
# Out:
# 4764

# %%
import pandas as pd 
fifadf=pd.read_csv("players_20.csv")
max_age=fifadf.age.max()
print(max_age)
# Out:
# 42

# %%
import pandas as pd 
fifadf=pd.read_csv("players_20.csv")
avg_age=fifadf.age.mean()
print(avg_age)
# Out:
# 25.283291388554545

# %%
import pandas as pd 
fifadf=pd.read_csv("players_20.csv")
for i in fifadf.index:
  if fifadf.club[i]=='FC Barcelona':
    print(fifadf.short_name[i])
# Out:
# L. Messi
# M. ter Stegen
# L. Suárez
# Sergio Busquets
# A. Griezmann
# Piqué
# Jordi Alba
# S. Umtiti
# I. Rakitić
# F. de Jong
# C. Lenglet
# Neto
# O. Dembélé
# Arthur
# A. Vidal
# Nélson Semedo
# Sergi Roberto
# Rafinha
# Junior Firpo
# Aleñá
# Riqui Puig
# J. Todibo
# M. Wagué
# H. Abe
# L. Reis
# Abel Ruiz
# Oriol Busquets
# Carles Pérez
# Miranda
# Chumi
# Álex Collado
# Jorge Cuenca
# Iñaki Peña
